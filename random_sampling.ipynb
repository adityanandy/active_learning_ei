# %%
import sys, time, pickle
import sklearn.preprocessing
from scipy import stats
import pandas as pd
import colorlover as cl
import numpy as np
from _plotly_future_ import v4_subplots
import plotly.graph_objs as go
import plotly.io as pio
import plotly
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.figure_factory as ff
plotly.io.orca.config.executable = '/anaconda2/envs/pytorch/bin/orca'
init_notebook_mode(connected=True)

glob_layout = go.Layout(
    font=dict(family='Helvetica', size=24, color='black'),
    margin=dict(l=100, r=10, t=10, b=100),
    xaxis=dict(showgrid=False,  zeroline=False, ticks="inside", showline=True,
               tickwidth=3, linewidth=3, ticklen=10,
               mirror="allticks", color="black"),
    yaxis=dict(showgrid=False,  zeroline=False, ticks="inside", showline=True,
               tickwidth=3, linewidth=3, ticklen=10,
               mirror="allticks", color="black"),
    legend_orientation="v",
)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
from perato_utils import is_pareto, area_under_pareto
from plot_utils import * # plot_pareto_front comes from here
from gpr import process_generation_2DEI, gp_predict
from ei import getEiVec2D_aug, get_ei_samples_kmeans, get_ei_samples_kmedoids
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
fnames = pickle.load(open('fnames.pkl', 'rb'))
df = pd.read_json('df_RAC155_homogap.json', orient='records', lines=True)
df = df.sample(n=int(1*len(df)), random_state=0)
df = df.reset_index()
y1l = 'alphaHOMO'
y2l = 'gap'

# %%
df_all = df.copy()
calibration_points = df.sample(n=int(100), random_state=1234)
df = df[~df["unique_name"].isin(calibration_points['unique_name'].values)]

# %%
tb_count = 0
tot_gen = 100
points_per_gen = 150
start_percentage = 1
known_points = df.sample(n=int(start_percentage*0.01*len(df)), random_state=1234)
pareto_inds_known, pareto_points_known = is_pareto(points=known_points[[y1l, y2l]].values)
print(len(known_points))
run_name = "100percent/random/start%d_initpoints_%d_totgen_%d_points_%d"%(start_percentage, len(known_points), tot_gen, points_per_gen)
basepath = '2DEI_alphaHOMO_gap/demo/%s/' % run_name
# Out:
# 150

# %%
pareto_inds, pareto_points = is_pareto(points=df[[y1l, y2l]].values)
plot_pareto_front(df, pareto_points, y1l, y2l,
                  figname=basepath + 'global_pareto_front.pdf',
                  range1=[-1.05, 0], range2=[0, 0.35])
# Out:
# <div>                            <div id="10030269-4ddc-44a5-a2d4-d63f50f3778e" class="plotly-graph-div" style="height:500px; width:500px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("10030269-4ddc-44a5-a2d4-d63f50f3778e")) {                    Plotly.newPlot(                        "10030269-4ddc-44a5-a2d4-d63f50f3778e",                        [{"marker":{"color":"black","size":5},"mode":"markers","opacity":0.5,"x":[-0.5872,-0.17,-0.5344,-0.4461,-0.608,-0.39490000000000003,-0.5505,-0.522,-0.3604,-0.6419,-0.4274,-0.7207,-0.5361,-0.0519,-0.7006,-0.2396,-0.4783,-0.8956000000000001,-0.7254,-0.7363000000000001,-0.5568000000000001,-0.7625000000000001,-0.49510000000000004,-0.46830000000000005,-0.1746,-0.5552,-0.5518000000000001,-0.4761,-0.5811000000000001,-0.3911,-0.492,-0.5745,-0.0646,-0.4435,-0.4572,-0.7668,-0.1398,-0.0172,-0.4581,-0.3042,-0.4323,-0.7321000000000001,-0.4672,-0.39330000000000004,-0.3111,-0.441,-0.4726,-0.2927,-0.4897,-0.3164,-0.4239,-0.7132000000000001,-0.44880000000000003,-0.4827,-0.5082,-0.4106,-0.1678,-0.5218,-0.5393,-0.7071000000000001,-0.0733,-0.4887,-0.5087,-0.24180000000000001,-0.325,-0.1208,-0.364,-0.3819,-0.3728,-0.5191,-0.5801000
pareto_list = []
# In each generation, new known points are added.
while tb_count < tot_gen:
    tb_count += 1
    print("=====gen-%d=====" % tb_count)
    df['known'] = [True if idx in list(
        known_points.index) else False for idx, row in df.iterrows()]
    known_points = df[df['known'] == True]
    known_list.append(known_points)
    pareto_list.append(pareto_points_known)
    df_unknown = df[df['known']==False]
    new_points = df_unknown.sample(n=points_per_gen, random_state=0)
    print("adding %d points using random sampling." % len(new_points))
    known_points = known_points.append(new_points[known_points.columns])
    pareto_inds_known, pareto_points_known = is_pareto(
        points=known_points[[y1l, y2l]].values)
    plot_pareto_front(known_list[-1], pareto_list[-1], y1l, y2l,
                      global_fronts=pareto_points,
                      next_fronts=pareto_points_known,
                      next_points=new_points,
                      figname=basepath + '/actual_pareto_gen-%d_len%d.pdf' % (tb_count, len(known_points)),
                      show=False, range1=[-1, 0], range2=[0, 0.35])
    print("ellapse: ", time.time() - start)
# Out:
# =====gen-1=====
# adding 150 points using kmedoids.
# ellapse:  3.773862838745117
# =====gen-2=====
# adding 150 points using kmedoids.
# ellapse:  7.209054946899414
# =====gen-3=====
# adding 150 points using kmedoids.
# ellapse:  11.571571826934814
# =====gen-4=====
# adding 150 points using kmedoids.
# ellapse:  15.943374872207642
# =====gen-5=====
# adding 150 points using kmedoids.
# ellapse:  21.509262800216675
# =====gen-6=====
# adding 150 points using kmedoids.
# ellapse:  27.493034839630127
# =====gen-7=====
# adding 150 points using kmedoids.
# ellapse:  31.998856782913208
# =====gen-8=====
# adding 150 points using kmedoids.
# ellapse:  36.642390966415405
# =====gen-9=====
# adding 150 points using kmedoids.
# ellapse:  41.74357295036316
# =====gen-10=====
# adding 150 points using kmedoids.
# ellapse:  46.94443988800049
# =====gen-11=====
# adding 150 points using kmedoids.
# ellapse:  53.46531677246094
# =====gen-12=====
# adding 150 points using kmedoids.
# ellapse:  59.91598677635193
# =====gen-13=====
# adding 150 points using kmedoids.
# ellapse:  67.21432495117188
# =====gen-14=====
# adding 150 points using kmedoids.
# ellapse:  74.16872978210449
# =====gen-15=====
# adding 150 points using kmedoids.
# ellapse:  81.63952088356018
# =====gen-16=====
# adding 150 points using kmedoids.
# ellapse:  88.58584880828857
# =====gen-17=====
# adding 150 points using kmedoids.
# ellapse:  96.2289469242096
# =====gen-18=====
# adding 150 points using kmedoids.
# ellapse:  103.39354276657104
# =====gen-19=====
# adding 150 points using kmedoids.
# ellapse:  111.63085079193115
# =====gen-20=====
# adding 150 points using kmedoids.
# ellapse:  119.94610404968262
# =====gen-21=====
# adding 150 points using kmedoids.
# ellapse:  129.2640027999878
# =====gen-22=====
# adding 150 points using kmedoids.
# ellapse:  137.86015677452087
# =====gen-23=====
# adding 150 points using kmedoids.
# ellapse:  146.65117001533508
# =====gen-24=====
# adding 150 points using kmedoids.
# ellapse:  156.1806719303131
# =====gen-25=====
# adding 150 points using kmedoids.
# ellapse:  165.21820783615112
# =====gen-26=====
# adding 150 points using kmedoids.
# ellapse:  175.27104473114014
# =====gen-27=====
# adding 150 points using kmedoids.
# ellapse:  185.66417789459229
# =====gen-28=====
# adding 150 points using kmedoids.
# ellapse:  196.46100974082947
# =====gen-29=====
# adding 150 points using kmedoids.
# ellapse:  206.37342166900635
# =====gen-30=====
# adding 150 points using kmedoids.
# ellapse:  216.87967491149902
# =====gen-31=====
# adding 150 points using kmedoids.
# ellapse:  227.6760377883911
# =====gen-32=====
# adding 150 points using kmedoids.
# ellapse:  238.78781485557556
# =====gen-33=====
# adding 150 points using kmedoids.
# ellapse:  249.7908227443695
# =====gen-34=====
# adding 150 points using kmedoids.
# ellapse:  261.3842329978943
# =====gen-35=====
# adding 150 points using kmedoids.
# ellapse:  274.2324957847595
# =====gen-36=====
# adding 150 points using kmedoids.
# ellapse:  286.31630992889404
# =====gen-37=====
# adding 150 points using kmedoids.
# ellapse:  299.72878789901733
# =====gen-38=====
# adding 150 points using kmedoids.
# ellapse:  313.0792577266693
# =====gen-39=====
# adding 150 points using kmedoids.
# ellapse:  326.1267488002777
# =====gen-40=====
# adding 150 points using kmedoids.
# ellapse:  339.1897418498993
# =====gen-41=====
# adding 150 points using kmedoids.
# ellapse:  353.26842069625854
# =====gen-42=====
# adding 150 points using kmedoids.
# ellapse:  367.20708179473877
# =====gen-43=====
# adding 150 points using kmedoids.
# ellapse:  381.90115189552307
# =====gen-44=====
# adding 150 points using kmedoids.
# ellapse:  396.2661738395691
# =====gen-45=====
# adding 150 points using kmedoids.
# ellapse:  411.16513204574585
# =====gen-46=====
# adding 150 points using kmedoids.
# ellapse:  426.5150640010834
# =====gen-47=====
# adding 150 points using kmedoids.
# ellapse:  441.7695949077606
# =====gen-48=====
# adding 150 points using kmedoids.
# ellapse:  457.13026785850525
# =====gen-49=====
# adding 150 points using kmedoids.
# ellapse:  472.9505019187927
# =====gen-50=====
# adding 150 points using kmedoids.
# ellapse:  489.55272793769836
# =====gen-51=====
# adding 150 points using kmedoids.
# ellapse:  505.5595498085022
# =====gen-52=====
# adding 150 points using kmedoids.
# ellapse:  521.2701478004456
# =====gen-53=====
# adding 150 points using kmedoids.
# ellapse:  537.2778539657593
# =====gen-54=====
# adding 150 points using kmedoids.
# ellapse:  553.7161729335785
# =====gen-55=====
# adding 150 points using kmedoids.
# ellapse:  570.8296129703522
# =====gen-56=====
# adding 150 points using kmedoids.
# ellapse:  588.4293129444122
# =====gen-57=====
# adding 150 points using kmedoids.
# ellapse:  605.6444499492645
# =====gen-58=====
# adding 150 points using kmedoids.
# ellapse:  623.5648167133331
# =====gen-59=====
# adding 150 points using kmedoids.
# ellapse:  641.2291529178619
# =====gen-60=====
# adding 150 points using kmedoids.
# ellapse:  661.5959649085999
# =====gen-61=====
# adding 150 points using kmedoids.
# ellapse:  680.9761788845062
# =====gen-62=====
# adding 150 points using kmedoids.
# ellapse:  700.2872278690338
# =====gen-63=====
# adding 150 points using kmedoids.
# ellapse:  719.7345447540283
# =====gen-64=====
# adding 150 points using kmedoids.
# ellapse:  739.2171719074249
# =====gen-65=====
# adding 150 points using kmedoids.
# ellapse:  758.9547357559204
# =====gen-66=====
# adding 150 points using kmedoids.
# ellapse:  779.5416367053986
# =====gen-67=====
# adding 150 points using kmedoids.
# ellapse:  800.0139100551605
# =====gen-68=====
# adding 150 points using kmedoids.
# ellapse:  821.0739238262177
# =====gen-69=====
# adding 150 points using kmedoids.
# ellapse:  842.2392950057983
# =====gen-70=====
# adding 150 points using kmedoids.
# ellapse:  862.625168800354
# =====gen-71=====
# adding 150 points using kmedoids.
# ellapse:  882.4909250736237
# =====gen-72=====
# adding 150 points using kmedoids.
# ellapse:  903.1351017951965
# =====gen-73=====
# adding 150 points using kmedoids.
# ellapse:  924.655158996582
# =====gen-74=====
# adding 150 points using kmedoids.
# ellapse:  950.4478619098663
# =====gen-75=====
# adding 150 points using kmedoids.
# ellapse:  973.1008248329163
# =====gen-76=====
# adding 150 points using kmedoids.
# ellapse:  995.8882539272308
# =====gen-77=====
# adding 150 points using kmedoids.
# ellapse:  1018.8205769062042
# =====gen-78=====
# adding 150 points using kmedoids.
# ellapse:  1042.246233701706
# =====gen-79=====
# adding 150 points using kmedoids.
# ellapse:  1065.4925849437714
# =====gen-80=====
# adding 150 points using kmedoids.
# ellapse:  1089.3093147277832
# =====gen-81=====
# adding 150 points using kmedoids.
# ellapse:  1111.97607088089
# =====gen-82=====
# adding 150 points using kmedoids.
# ellapse:  1136.6854038238525
# =====gen-83=====
# adding 150 points using kmedoids.
# ellapse:  1160.0619246959686
# =====gen-84=====
# adding 150 points using kmedoids.
# ellapse:  1184.1537237167358
# =====gen-85=====
# adding 150 points using kmedoids.
# ellapse:  1208.4341478347778
# =====gen-86=====
# adding 150 points using kmedoids.
# ellapse:  1232.47056889534
# =====gen-87=====
# adding 150 points using kmedoids.
# ellapse:  1256.759673833847
# =====gen-88=====
# adding 150 points using kmedoids.
# ellapse:  1281.5681269168854
# =====gen-89=====
# adding 150 points using kmedoids.
# ellapse:  1309.899966955185
# =====gen-90=====
# adding 150 points using kmedoids.
# ellapse:  1336.3178579807281
# =====gen-91=====
# adding 150 points using kmedoids.
# ellapse:  1362.3188648223877
# =====gen-92=====
# adding 150 points using kmedoids.
# ellapse:  1389.5318138599396
# =====gen-93=====
# adding 150 points using kmedoids.
# ellapse:  1415.8876328468323
# =====gen-94=====
# adding 150 points using kmedoids.
# ellapse:  1443.7318058013916
# =====gen-95=====
# adding 150 points using kmedoids.
# ellapse:  1470.438286781311
# =====gen-96=====
# adding 150 points using kmedoids.
# ellapse:  1496.6414799690247
# =====gen-97=====
# adding 150 points using kmedoids.
# ellapse:  1523.8314468860626
# =====gen-98=====
# adding 150 points using kmedoids.
# ellapse:  1551.4838950634003
# =====gen-99=====
# adding 150 points using kmedoids.
# ellapse:  1578.5923418998718
# =====gen-100=====
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-a22242c44ac7> in <module>
#      12     pareto_list.append(pareto_points_known)
#      13     df_unknown = df[df['known']==False]
# ---> 14     new_points = df_unknown.sample(n=points_per_gen, random_state=0)
#      15     print("adding %d points using kmedoids." % len(new_points))
#      16     known_points = known_points.append(new_points[known_points.columns])
#
# /anaconda2/envs/pytorch/lib/python3.6/site-packages/pandas/core/generic.py in sample(self, n, frac, replace, weights, random_state, axis)
#    4863                              "provide positive value.")
#    4864
# -> 4865         locs = rs.choice(axis_length, size=n, replace=replace, p=weights)
#    4866         return self.take(locs, axis=axis, is_copy=False)
#    4867
#
# mtrand.pyx in mtrand.RandomState.choice()
#
# ValueError: Cannot take a larger sample than population when 'replace=False'

# %%
area_global = area_under_pareto(pareto_points, pareto_points)
pareto_area_list = [area_global/area_under_pareto(pareto_list[gen], pareto_points)  for gen in range(tot_gen)]
coverage_list = [len(known_list[gen])*1./len(df) for gen in range(tot_gen)]
plot_pareto_area(coverage_list, pareto_area_list,
                 figname=basepath+'area_under_pareto.pdf', show=True)
with open(basepath + "coverage_list.pkl", 'wb') as fo:
    pickle.dump(coverage_list, fo)
with open(basepath + "pareto_area_list.pkl", 'wb') as fo:
    pickle.dump(pareto_area_list, fo)
